# %% [markdown]
# # TP2 - Notebook de experimentacion
#
# Sistema de Deteccion y Clasificacion de Razas de Perros.
#
# Pipeline: **Embeddings -> Busqueda por similitud -> Clasificacion -> Deteccion -> Pipeline completo**

# %% [markdown]
# ## Equipo
# - Alumno 1 :
# - Alumno 2 :

# %%
# Setup: permite importar los modulos del proyecto desde la notebook.
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd() / "src"))

from lib.config import settings
from lib.evaluation import metrics
from lib.visualization import draw

print(settings.dataset_path)

# %% [markdown]
# ## Dataset
#
# TO-DO:
# - Descargar el dataset `70 Dog Breeds Image Dataset` (`python scripts/download_dataset.py`).
# - Analizar la distribucion de clases y documentar la cantidad de imagenes por raza.
# - Definir los conjuntos de entrenamiento, validacion y prueba.
# - Construir un conjunto independiente para evaluacion (ej: imagenes descargadas de internet).

# %%
## TO-DO: analisis exploratorio del dataset (distribucion de clases, imagenes por raza).

# %% [markdown]
# ## Preprocesamiento
#
# TO-DO: definir y justificar resize, normalizacion, data augmentation (horizontal flip,
# rotacion, blur, brillo, contraste, ruido) y filtrado de imagenes de baja calidad.

# %%
## TO-DO: transformaciones de preprocesamiento y data augmentation.

# %% [markdown]
# ## Etapa 1: Buscador de imagenes por similitud
#
# TO-DO:
# - Implementar `extract_embedding`, `search_similar_images` y `predict_breed_from_neighbors`
#   en `src/lib/services/similarity_service.py`.
# - Indexar el dataset (`python scripts/build_index.py`).
# - Visualizar los embeddings con PCA o t-SNE.
# - Evaluar con NDCG@10 sobre el conjunto de prueba independiente (`lib.evaluation.metrics.ndcg_at_k`)
#   y justificar el resultado.

# %%
## TO-DO: experimentos de la Etapa 1 (embeddings, busqueda, NDCG@10, PCA/t-SNE).

# %% [markdown]
# ## Etapa 2: Entrenamiento y comparacion de modelos
#
# TO-DO:
# - Modelo A (obligatorio): fine-tuning de ResNet18 pre-entrenado.
# - Modelo B (opcional, recomendado): CNN propia.
# - Implementar `train_classifier`, `evaluate_classifier` y `extract_custom_embedding`
#   en `src/lib/services/classifier_service.py`.
# - Reportar accuracy, precision, recall, specificity y F1-Score.
# - Incluir matriz de confusion, curvas de entrenamiento y comparacion entre modelos.
# - Guardar los checkpoints en `models/` (ver RESNET18_MODEL_NAME / CNN_CUSTOM_MODEL_NAME en .env).

# %%
## TO-DO: entrenamiento, metricas, matriz de confusion y curvas de la Etapa 2.

# %% [markdown]
# ## Etapa 3: Pipeline de deteccion y clasificacion
#
# TO-DO:
# - Implementar `detect_dogs` y `classify_detected_dog` en `src/lib/services/detection_service.py`
#   (YOLO pre-entrenado, ej: YOLOv8n; no es necesario entrenar el detector).
# - Probar con un perro, multiples perros y escenas complejas con otros objetos.
# - Visualizar resultados con `lib.visualization.draw.draw_detections`.

# %%
## TO-DO: pruebas del pipeline de deteccion + clasificacion.

# %% [markdown]
# ## Etapa 4: Evaluacion, optimizacion y anotacion automatica
#
# TO-DO:
# - Construir el conjunto de prueba en `data/eval` (al menos 10 imagenes complejas
#   anotadas manualmente con bounding boxes y raza).
# - Implementar `evaluate_pipeline`, `optimize_model` y `generate_annotations`
#   en `src/lib/services/pipeline_service.py`.
# - Calcular mAP, IoU, precision, recall y F1 (`lib.evaluation.metrics`) y analizar resultados
#   (incluyendo falsos positivos y falsos negativos).
# - Comparar el modelo optimizado vs el original: tiempo de inferencia, memoria y precision.
# - Generar anotaciones YOLOv5 y COCO (`python scripts/generate_annotations.py <carpeta> --format yolo|coco`).

# %%
## TO-DO: evaluacion del pipeline, optimizacion y anotaciones de la Etapa 4.
